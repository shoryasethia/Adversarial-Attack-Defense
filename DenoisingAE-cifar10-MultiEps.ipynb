# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %%
import numpy as np
import tensorflow as tf
from keras import datasets, models, layers 
import time
from matplotlib import pyplot as plt
# Out:
# 2024-07-05 13:22:59.222306: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-05 13:22:59.222423: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-05 13:22:59.346424: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
(X_train, _), (X_test, _ ) = datasets.cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 17s 0us/step

# %%
X_train.shape
X_test.shape
# Out:
# (50000, 32, 32, 3)
# (10000, 32, 32, 3)

# %%
def subplt (rows, cols, img):
  plt_img = img[:rows*cols]
  for i in range(len(plt_img)):
    plt.subplot(rows, cols, i+1)
    plt.imshow(plt_img[i], cmap = 'gray')
    plt.axis('off')
  
  return

# %%
subplt(5,5,X_train)

# %%
X_train.max()
# Out:
# 255

# %%
X_train = X_train / 255.0
X_test = X_test / 255.0

# %%
min_factor = 0.01
max_factor = 0.15

# Assuming batch_noise_factors is generated as before
batch_noise_factors_train = np.random.uniform(min_factor, max_factor, size=(len(X_train), 1, 1, 1))
batch_noise_factors_test = np.random.uniform(min_factor, max_factor, size=(len(X_test), 1, 1, 1))

# Example reshaping for noise addition
X_train_noise = X_train + batch_noise_factors_train * np.random.normal(loc=0, scale=1.0, size=X_train.shape)
X_test_noise = X_test + batch_noise_factors_test * np.random.normal(loc=0, scale=1.0, size=X_test.shape)

# %%
subplt(5,5,X_train_noise)

# %%
X_train = X_train.reshape(X_train.shape[0],32,32,3)
X_test = X_test.reshape(X_test.shape[0],32,32,3)
X_train_noise = X_train_noise.reshape(X_train_noise.shape[0],32,32,3)
X_test_noise = X_test_noise.reshape(X_test_noise.shape[0],32,32,3)

# %% [markdown]
# ## Creating Autoencoder Model

# %%
from tensorflow.keras import layers, models

input_shape = (32,32,3)
input_layer = layers.Input(shape=input_shape, name='Input_Layer')

# Encoder
x = layers.Conv2D(64, (3, 3), strides=(1, 1), padding='same', activation='relu', kernel_initializer='he_uniform')(input_layer)
x = layers.MaxPooling2D((2, 2))(x)

x = layers.Conv2D(128, (3, 3), strides=(2, 2), padding='same', activation='relu', kernel_initializer='he_uniform')(x)
x = layers.BatchNormalization()(x)
x = layers.MaxPooling2D((2, 2))(x)

x = layers.Conv2D(256, (3, 3), strides=(2, 2), padding='same', activation='relu', kernel_initializer='he_uniform')(x)
x = layers.BatchNormalization()(x)
encoded_layer = layers.MaxPooling2D((2, 2), name='Encoded_Layer')(x)

# Decoder
x = layers.Conv2DTranspose(256, (3, 3), strides=(2, 2), padding='same', activation='relu', kernel_initializer='he_uniform')(encoded_layer)
x = layers.BatchNormalization()(x)
x = layers.UpSampling2D((2, 2))(x)

x = layers.Conv2DTranspose(128, (3, 3), strides=(2, 2), padding='same', activation='relu', kernel_initializer='he_uniform')(x)
x = layers.BatchNormalization()(x)
x = layers.UpSampling2D((2, 2))(x)

x = layers.Conv2DTranspose(64, (3, 3), strides=(2, 2), padding='same', activation='relu', kernel_initializer='he_uniform')(x)
x = layers.BatchNormalization()(x)

decoded_layer = layers.Conv2DTranspose(3, (3, 3), strides=(1, 1), padding='same', activation='sigmoid', kernel_initializer='he_uniform', name='Decoded_Layer')(x)

# Output
output_layer = decoded_layer
dae = models.Model(inputs=input_layer, outputs=output_layer, name='dae-cifar10')

dae.summary()
# Out:
# Model: "dae-cifar10"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ Input_Layer (InputLayer)        │ (None, 32, 32, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 32, 32, 64)     │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 8, 8, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 8, 8, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 2, 2, 256)      │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 2, 2, 256)      │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Encoded_Layer (MaxPooling2D)    │ (None, 1, 1, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose                │ (None, 2, 2, 256)      │       590,080 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 2, 2, 256)      │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d (UpSampling2D)    │ (None, 4, 4, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_1              │ (None, 8, 8, 128)      │       295,040 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 8, 8, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_1 (UpSampling2D)  │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_2              │ (None, 32, 32, 64)     │        73,792 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 32, 32, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Decoded_Layer (Conv2DTranspose) │ (None, 32, 32, 3)      │         1,731 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,334,787 (5.09 MB)
#  Trainable params: 1,333,123 (5.09 MB)
#  Non-trainable params: 1,664 (6.50 KB)

# %%
dae.compile(optimizer = 'adam', loss = 'mse')

# %%
epochs = 50
batch_size = 256

# Start time measurement
start = time.time()

# Training loop
history = dae.fit(
    x=X_train_noise, y=X_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_data=(X_test_noise, X_test),
    verbose=1
)

# Calculate and print time consumed
print(f"Time consumed = {time.time()-start} seconds")
# Out:
# Epoch 1/50
#   7/196 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - loss: 0.2076
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1720185834.626686      85 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 20s 52ms/step - loss: 0.0641 - val_loss: 0.0273
# Epoch 2/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 20ms/step - loss: 0.0226 - val_loss: 0.0209
# Epoch 3/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 0.0187 - val_loss: 0.0201
# Epoch 4/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 20ms/step - loss: 0.0167 - val_loss: 0.0169
# Epoch 5/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 20ms/step - loss: 0.0155 - val_loss: 0.0166
# Epoch 6/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 0.0147 - val_loss: 0.0156
# Epoch 7/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 20ms/step - loss: 0.0145 - val_loss: 0.0154
# Epoch 8/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 0.0139 - val_loss: 0.0190
# Epoch 9/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 0.0159 - val_loss: 0.0141
# Epoch 10/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 0.0135 - val_loss: 0.0138
# Epoch 11/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 0.0131 - val_loss: 0.0133
# Epoch 12/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 0.0127 - val_loss: 0.0131
# Epoch 13/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 0.0131 - val_loss: 0.0131
# Epoch 14/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 0.0126 - val_loss: 0.0128
# Epoch 15/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 0.0122 - val_loss: 0.0130
# Epoch 16/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 0.0123 - val_loss: 0.0121
# Epoch 17/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 0.0119 - val_loss: 0.0134
# Epoch 18/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 0.0119 - val_loss: 0.0120
# Epoch 19/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 0.0116 - val_loss: 0.0114
# Epoch 20/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 0.0115 - val_loss: 0.0191
# Epoch 21/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 0.0115 - val_loss: 0.0117
# Epoch 22/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 0.0112 - val_loss: 0.0114
# Epoch 23/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 0.0111 - val_loss: 0.0112
# Epoch 24/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 0.0115 - val_loss: 0.0133
# Epoch 25/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 0.0114 - val_loss: 0.0116
# Epoch 26/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 0.0110 - val_loss: 0.0111
# Epoch 27/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 0.0108 - val_loss: 0.0110
# Epoch 28/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 0.0107 - val_loss: 0.0110
# Epoch 29/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 0.0106 - val_loss: 0.0109
# Epoch 30/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 0.0107 - val_loss: 0.0109
# Epoch 31/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 0.0106 - val_loss: 0.0106
# Epoch 32/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 0.0104 - val_loss: 0.0111
# Epoch 33/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 0.0104 - val_loss: 0.0171
# Epoch 34/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 0.0128 - val_loss: 0.0121
# Epoch 35/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 0.0106 - val_loss: 0.0107
# Epoch 36/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 0.0103 - val_loss: 0.0108
# Epoch 37/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 0.0103 - val_loss: 0.0109
# Epoch 38/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 0.0103 - val_loss: 0.0104
# Epoch 39/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 0.0102 - val_loss: 0.0103
# Epoch 40/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 0.0104 - val_loss: 0.0106
# Epoch 41/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 0.0101 - val_loss: 0.0100
# Epoch 42/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.0100 - val_loss: 0.0100
# Epoch 43/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 0.0099 - val_loss: 0.0109
# Epoch 44/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 0.0099 - val_loss: 0.0099
# Epoch 45/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 0.0098 - val_loss: 0.0102
# Epoch 46/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 0.0098 - val_loss: 0.0104
# Epoch 47/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 0.0097 - val_loss: 0.0101
# Epoch 48/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 0.0098 - val_loss: 0.0100
# Epoch 49/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 0.0097 - val_loss: 0.0099
# Epoch 50/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 0.0097 - val_loss: 0.0097
# Time consumed = 225.4027168750763 seconds

# %%
plt.figure()
plt.plot(history.history['loss'], label='Training Loss')
if 'val_loss' in history.history:
    plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title(f"Loss (epochs={epochs}, batch_size={batch_size})")
plt.grid(True)
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()
# Out:
# Text(0.5, 1.0, 'Loss (epochs=50, batch_size=256)')
# Text(0.5, 0, 'Epochs')
# Text(0, 0.5, 'Loss')

# %%
dae.save("DAE-CIFAR10.h5")

# %%
encoder = models.Model(inputs = input_layer, outputs = encoded_layer)
encoder.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ Input_Layer (InputLayer)        │ (None, 32, 32, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 32, 32, 64)     │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 8, 8, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 8, 8, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 2, 2, 256)      │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 2, 2, 256)      │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Encoded_Layer (MaxPooling2D)    │ (None, 1, 1, 256)      │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 372,352 (1.42 MB)
#  Trainable params: 371,584 (1.42 MB)
#  Non-trainable params: 768 (3.00 KB)

# %%
decoder = models.Model(inputs = encoded_layer, outputs = decoded_layer)
decoder.summary()
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ keras_tensor_7CLONE             │ (None, 1, 1, 256)      │             0 │
# │ (InputLayer)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose                │ (None, 2, 2, 256)      │       590,080 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 2, 2, 256)      │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d (UpSampling2D)    │ (None, 4, 4, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_1              │ (None, 8, 8, 128)      │       295,040 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 8, 8, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_1 (UpSampling2D)  │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_2              │ (None, 32, 32, 64)     │        73,792 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 32, 32, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Decoded_Layer (Conv2DTranspose) │ (None, 32, 32, 3)      │         1,731 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 962,435 (3.67 MB)
#  Trainable params: 961,539 (3.67 MB)
#  Non-trainable params: 896 (3.50 KB)

# %% [markdown]
# ## Testing model on testing data

# %%
rows = 9
cols = 3

indices = np.random.randint(0, len(X_test_noise), rows)

test_noise_images = X_test_noise[indices]
test_images = X_test[indices]

encoded_imgs = encoder.predict(test_noise_images)
reconstructed_images = decoder.predict(encoded_imgs)

plt.figure(figsize=(cols*2, rows*2))

for i in range(len(indices)):
    # Noisy image
    plt.subplot(rows, cols, 3*i + 1)
    plt.imshow(test_noise_images[i].reshape(32, 32,3))
    plt.title('Noisy')
    plt.axis('off')

    # Original denoised image
    plt.subplot(rows, cols, 3*i + 2)
    plt.imshow(test_images[i].reshape(32, 32,3))
    plt.title('Original Denoised')
    plt.axis('off')

    # Reconstructed image
    plt.subplot(rows, cols, 3*i + 3)
    plt.imshow(reconstructed_images[i].reshape(32, 32,3))
    plt.title('Generative Denoised')
    plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 445ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 562ms/step
# <Axes: >
# Text(0.5, 1.0, 'Noisy')
# (-0.5, 31.5, 31.5, -0.5)
# <Axes: >
# Text(0.5, 1.0, 'Original Denoised')
# (-0.5, 31.5, 31.5, -0.5)
# <Axes: >
# Text(0.5, 1.0, 'Generative Denoised')
# (-0.5, 31.5, 31.5, -0.5)
# <Axes: >
# Text(0.5, 1.0, 'Noisy')
# (-0.5, 31.5, 31.5, -0.5)
# <Axes: >
# Text(0.5, 1.0, 'Original Denoised')
# (-0.5, 31.5, 31.5, -0.5)
# <Axes: >
# Text(0.5, 1.0, 'Generative Denoised')
# (-0.5, 31.5, 31.5, -0.5)
# <Axes: >
# Text(0.5, 1.0, 'Noisy')
# (-0.5, 31.5, 31.5, -0.5)
# <Axes: >
# Text(0.5, 1.0, 'Original Denoised')
# (-0.5, 31.5, 31.5, -0.5)
# <Axes: >
# Text(0.5, 1.0, 'Generative Denoised')
# (-0.5, 31.5, 31.5, -0.5)
# <Axes: >
# Text(0.5, 1.0, 'Noisy')
# (-0.5, 31.5, 31.5, -0.5)
# <Axes: >
# Text(0.5, 1.0, 'Original Denoised')
# (-0.5, 31.5, 31.5, -0.5)
# <Axes: >
# Text(0.5, 1.0, 'Generative Denoised')
# (-0.5, 31.5, 31.5, -0.5)
# <Axes: >
# Text(0.5, 1.0, 'Noisy')
# (-0.5, 31.5, 31.5, -0.5)
# <Axes: >
# Text(0.5, 1.0, 'Original Denoised')
# (-0.5, 31.5, 31.5, -0.5)
# <Axes: >
# Text(0.5, 1.0, 'Generative Denoised')
# (-0.5, 31.5, 31.5, -0.5)
# <Axes: >
# Text(0.5, 1.0, 'Noisy')
# (-0.5, 31.5, 31.5, -0.5)
# <Axes: >
# Text(0.5, 1.0, 'Original Denoised')
# (-0.5, 31.5, 31.5, -0.5)
# <Axes: >
# Text(0.5, 1.0, 'Generative Denoised')
# (-0.5, 31.5, 31.5, -0.5)
# <Axes: >
# Text(0.5, 1.0, 'Noisy')
# (-0.5, 31.5, 31.5, -0.5)
# <Axes: >
# Text(0.5, 1.0, 'Original Denoised')
# (-0.5, 31.5, 31.5, -0.5)
# <Axes: >
# Text(0.5, 1.0, 'Generative Denoised')
# (-0.5, 31.5, 31.5, -0.5)
# <Axes: >
# Text(0.5, 1.0, 'Noisy')
# (-0.5, 31.5, 31.5, -0.5)
# <Axes: >
# Text(0.5, 1.0, 'Original Denoised')
# (-0.5, 31.5, 31.5, -0.5)
# <Axes: >
# Text(0.5, 1.0, 'Generative Denoised')
# (-0.5, 31.5, 31.5, -0.5)
# <Axes: >
# Text(0.5, 1.0, 'Noisy')
# (-0.5, 31.5, 31.5, -0.5)
# <Axes: >
# Text(0.5, 1.0, 'Original Denoised')
# (-0.5, 31.5, 31.5, -0.5)
# <Axes: >
# Text(0.5, 1.0, 'Generative Denoised')
# (-0.5, 31.5, 31.5, -0.5)

# %%
from sklearn.metrics import mean_squared_error

test_noise = X_test_noise.reshape(X_test_noise.shape[0],-1)
test = X_test.reshape(X_test.shape[0],-1)

encoded = encoder.predict(X_test_noise)
pred = decoder.predict(encoded)
pred = pred.reshape(pred.shape[0],-1)

mse = mean_squared_error(test,pred)
print(f"mse = {mse}")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# mse = 0.009653996374322042
